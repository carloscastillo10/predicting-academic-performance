# %% [markdown]
# <a href="https://colab.research.google.com/github/carloscastillo10/predicting-academic-performance/blob/main/annex-e.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CASO 3
#
# En este caso se toma como referencia https://www.kaggle.com/code/devassaxd/student-performance-prediction-complete-analysis/notebook#Part-3:-Modeling y debe contener la siguiente estructura:
#
# | fake_identificacion | curso_nombre | numero_reprobaciones | status | aab1_nota | aab1_ponderado | acdb1_nota | acdb1_ponderado|	apeb1_nota | apeb1_ponderado | componentes_b2... | final_nota| final_ponderado | tasa_aprobacion |
# | ---- | ---- | ---- | ---- | ---- | ---- | ---- | ---- | ---- | ---- | ---- | ---- | ---- | ---- |
# | SLXA73875862178452 | nombre_materia_1 | num_repr_materia_1 | APROBADA | nota_aab1 | ponderado_aab1 | nota_acdb1 | ponderad_acdb1 | nota_acdb1 |ponderad_acdb1 | nota/ponderados__componentes_b2 | nota_final | ponderado_nota_final | tasa_aprobacion |
# | SLXA73875862178452 | nombre_materia_2 | num_repr_materia_2 | REPROBADA | nota_aab1 | ponderado_aab1 | nota_acdb1 | ponderad_acdb1 | nota_acdb1 |ponderad_acdb1 | nota/ponderados__componentes_b2 | nota_final | ponderado_nota_final | tasa_aprobacion |
# | SLXA73875862178452 | nombre_materia_3 | num_repr_materia_3 | APROBADA | nota_aab1 | ponderado_aab1 | nota_acdb1 | ponderad_acdb1 | nota_acdb1 |ponderad_acdb1 | nota/ponderados__componentes_b2 | nota_final | ponderado_nota_final | tasa_aprobacion |
# | SLXA73875862178452 | nombre_materia_4 | num_repr_materia_4 | REPROBADA | nota_aab1 | ponderado_aab1 | nota_acdb1 | ponderad_acdb1 | nota_acdb1 |ponderad_acdb1 | nota/ponderados__componentes_b2 | nota_final | ponderado_nota_final | tasa_aprobacion |
# | SLXA73875862178452 | nombre_materia_5 | num_repr_materia_5 | APROBADA | nota_aab1 | ponderado_aab1 | nota_acdb1 | ponderad_acdb1 | nota_acdb1 |ponderad_acdb1 | nota/ponderados__componentes_b2 | nota_final | ponderado_nota_final | tasa_aprobacion |
# | SLXA73875862178452 | nombre_materia_6 | num_repr_materia_6 | REPROBADA | nota_aab1 | ponderado_aab1 | nota_acdb1 | ponderad_acdb1 | nota_acdb1 |ponderad_acdb1 | nota/ponderados__componentes_b2 | nota_final | ponderado_nota_final | tasa_aprobacion |
# | SLXA73875862178452 | nombre_materia_7 | num_repr_materia_7 | APROBADA | nota_aab1 | ponderado_aab1 | nota_acdb1 | ponderad_acdb1 | nota_acdb1 |ponderad_acdb1 | nota/ponderados__componentes_b2 | nota_final | ponderado_nota_final | tasa_aprobacion |
# | SLXA73875862178452 | nombre_materia_8 | num_repr_materia_8 | APROBADA | nota_aab1 | ponderado_aab1 | nota_acdb1 | ponderad_acdb1 | nota_acdb1 |ponderad_acdb1 | nota/ponderados__componentes_b2 | nota_final | ponderado_nota_final | tasa_aprobacion |
# | SLXA73875862178452 | nombre_materia_9 | num_repr_materia_9 | APROBADA | nota_aab1 | ponderado_aab1 | nota_acdb1 | ponderad_acdb1 | nota_acdb1 |ponderad_acdb1 | nota/ponderados__componentes_b2 | nota_final | ponderado_nota_final | tasa_aprobacion |
# | SLXA73875862178452 | nombre_materia_10 | num_repr_materia_10 | APROBADA | nota_aab1 | ponderado_aab1 | nota_acdb | ponderad_acdb1 | nota_acdb1 |ponderad_acdb1 | nota/ponderados__componentes_b2 | nota_final | ponderado_nota_final | tasa_aprobacion |
# | SLXA73875862178452 | nombre_materia_n | num_repr_materia_n | REPROBADA | nota_aab1 | ponderado_aab1 | nota_acdb1 | ponderad_acdb1 | nota_acdb1 |ponderad_acdb1 | nota/ponderados__componentes_b2 | nota_final | ponderado_nota_final | tasa_aprobacion |
#
#
# Se tuvieron en cuenta los siguientes aspectos:
# * Se mantuvo las notas originales
# * Se obtuvo la nota ponderada (columna: *`ponderado`*) de cada componente.
#     * Por ejemplo si la nota del componente **`ACDB1`**  es de **`3.2`** y el peso de este componente es del **`35%`** y con una nota máxima de **`3.5`**, entonces se hace la regla de tres: `si la nota maxima (3.5) equivale al 35% a cuanto equivale la nota obtenida por un estudiante en ese componente (ACDB1)`
# * Se obtuvo la **`tasa de aprobacion`** total del componente, esta columna se calcula con la siguiente fórmula: `total de componentes aprobados` / `total de componentes totales de la materia`, para definir cuando se aprueba o reprueba un componente se toma como referencia la siguiente tabla:
#
# >> | componente | Descripcion | peso | nota máxima | nota mínima para aprobar |
# | ---------- | ---- | ---- | ----------- | ------------------------ |
# | ACDB1      | Aprendizaje en contacto con el docente primer bimestre | 35%  | 3.5         | 2.45                     |
# | APEB1      | Aprendizaje práctico experimental primer bimestre | 30%  | 3           | 2.41                     |
# | AAB1       | Aprendizaje autónomo primer bimestre | 35%  | 3.5         | 2.45                     |
# | ACDB2      | Aprendizaje en contacto con el docente segundo bimestre | 35%  | 3.5         | 2.45                     |
# | APEB2      | Aprendizaje práctico experimental segundo bimestre | 30%  | 3           | 2.41                     |
# | AAB2       | Aprendizaje autónomo segundo bimestre | 35%  | 3.5         | 2.45                     |
# | FINAL      | Nota final del bimestre | 100% | 10          | 7                        |

# %%
import pandas as pd
pd.options.display.max_columns = 50

# %% [markdown]
# ## Leer datos de estudiantes, actividades y notas

# %%
student_info_data = pd.read_csv('data/estudentInfo.csv')
assessments_data = pd.read_csv('data/assessments.csv')
student_assessments_data = pd.read_csv('data/studentAssessment.csv')

# %% [markdown]
# ## Actividades

# %%
final_scores = assessments_data[assessments_data.componente == 'FINAL']
component_scores = assessments_data[assessments_data.componente != 'FINAL']
amounts = component_scores.groupby(
    ['curso_nombre', 'codigo_periodo']
).count()['componente'].reset_index()

amounts[
    (amounts.curso_nombre == 'COMUNICACION DE DATOS')
    & (amounts.codigo_periodo == 202062)
]
# Out:
#              curso_nombre  codigo_periodo  componente
# 74  COMUNICACION DE DATOS          202062           6

# %%
component_approval_notes = {
    'ACDB1': {'max_note': 3.5, 'aproval_note': 2.45}, 
    'APEB1': {'max_note': 3, 'aproval_note': 2.1},
    'AAB1': {'max_note': 3.5, 'aproval_note': 2.45},
    'ACDB2': {'max_note': 3.5, 'aproval_note': 2.45}, 
    'APEB2': {'max_note': 3, 'aproval_note': 2.1},
    'AAB2': {'max_note': 3.5, 'aproval_note': 2.45},
    'FINAL': {'max_note': 10, 'aproval_note': 7}
}

def set_pass_fail(component, score):
    if score >= component_approval_notes[component]['aproval_note']:
        return True
    
    return False

def set_weighted_grade(component, score, weigth):
    max_note_component = component_approval_notes[component]['max_note']
    
    return round(((score * weigth) / max_note_component), 2)

student_assessments = pd.merge(
    student_assessments_data, 
    assessments_data,
    how = 'inner',
    on = ['curso_nombre', 'codigo_periodo', 'componente']
)

student_assessments['aprobado'] = student_assessments.apply(
    lambda row: set_pass_fail(row.componente, row.nota), 
    axis = 1
)

student_assessments['ponderado'] = student_assessments.apply(
    lambda row: set_weighted_grade(row.componente, row.nota, row.peso),
    axis = 1
)

student_assessments[
    (student_assessments.fake_identificacion == 'SLXA73875862178452')
    & (student_assessments.curso_nombre == 'COMUNICACION DE DATOS')
    & (student_assessments.codigo_periodo == 202062)
]
# Out:
#        fake_identificacion  codigo_periodo           curso_nombre componente  \
# 0       SLXA73875862178452          202062  COMUNICACION DE DATOS       AAB1
# 26210   SLXA73875862178452          202062  COMUNICACION DE DATOS      ACDB1
# 52420   SLXA73875862178452          202062  COMUNICACION DE DATOS      APEB1
# 78630   SLXA73875862178452          202062  COMUNICACION DE DATOS       AAB2
# 104840  SLXA73875862178452          202062  COMUNICACION DE DATOS      ACDB2
# 131050  SLXA73875862178452          202062  COMUNICACION DE DATOS      APEB2
# 157260  SLXA73875862178452          202062  COMUNICACION DE DATOS      FINAL
#
#         nota  peso  aprobado  ponderado
# 0       1.95    35     False       19.5
# 26210   3.33    35      True       33.3
# 52420   0.51    30     False        5.1
# 78630   2.01    35     False       20.1
# 104840  1.35    35     False       13.5
# 131050  1.55    30     False       15.5
# 157260  5.30   100     False       53.0

# %%
scores_data = pd.pivot(
    student_assessments,
    index = ['fake_identificacion', 'codigo_periodo', 'curso_nombre'],
    values = 'nota',
    columns = 'componente'
)
scores_data.columns = [f'{column_name.lower()}_nota' for column_name in scores_data.columns]
scores_data = scores_data.reset_index()

weigtheds_grade_data = pd.pivot(
    student_assessments,
    index = ['fake_identificacion', 'codigo_periodo', 'curso_nombre'],
    values = 'ponderado',
    columns = 'componente'
)
weigtheds_grade_data.columns = [f'{column_name.lower()}_ponderado' for column_name in weigtheds_grade_data.columns]
weigtheds_grade_data = weigtheds_grade_data.reset_index()

student_scores_weigtheds = pd.merge(
    scores_data,
    weigtheds_grade_data,
    how = 'inner',
    on = ['fake_identificacion', 'codigo_periodo', 'curso_nombre']
)

student_scores_weigtheds[
    (student_scores_weigtheds.fake_identificacion == 'SLXA73875862178452')
    & (student_scores_weigtheds.curso_nombre == 'COMUNICACION DE DATOS')
    & (student_scores_weigtheds.codigo_periodo == 202062)
]
# Out:
#       fake_identificacion  codigo_periodo           curso_nombre  aab1_nota  \
# 18255  SLXA73875862178452          202062  COMUNICACION DE DATOS       1.95
#
#        aab2_nota  acdb1_nota  acdb2_nota  apeb1_nota  apeb2_nota  final_nota  \
# 18255       2.01        3.33        1.35        0.51        1.55         5.3
#
#        aab1_ponderado  aab2_ponderado  acdb1_ponderado  acdb2_ponderado  \
# 18255            19.5            20.1             33.3             13.5
#
#        apeb1_ponderado  apeb2_ponderado  final_ponderado
# 18255              5.1             15.5             53.0

# %%
student_pass_rate = pd.merge(
    student_assessments[
        (student_assessments.aprobado == True)
        & (student_assessments.componente != 'FINAL')
    ].groupby(
        ['fake_identificacion', 'codigo_periodo', 'curso_nombre']
    ).count()['aprobado'].reset_index(),
    amounts,
    how = 'left',
    on = ['curso_nombre', 'codigo_periodo']
)

student_pass_rate['tasa_aprobacion'] = round((student_pass_rate['aprobado'] / student_pass_rate['componente']), 2)
student_pass_rate.drop(['aprobado', 'componente'], axis = 1, inplace = True)

student_pass_rate[
    (student_pass_rate.fake_identificacion == 'SLXA73875862178452')
    & (student_pass_rate.curso_nombre == 'COMUNICACION DE DATOS')
    & (student_pass_rate.codigo_periodo == 202062)
]
# Out:
#       fake_identificacion  codigo_periodo           curso_nombre  \
# 15906  SLXA73875862178452          202062  COMUNICACION DE DATOS
#
#        tasa_aprobacion
# 15906             0.17

# %% [markdown]
# # Integración de datos

# %%
assessment_info = pd.merge(
    student_scores_weigtheds,
    student_pass_rate,
    how = 'inner',
    on = ['fake_identificacion', 'codigo_periodo', 'curso_nombre']
)

assessment_info[
    (assessment_info.fake_identificacion == 'SLXA73875862178452')
    & (assessment_info.curso_nombre == 'COMUNICACION DE DATOS')
    & (assessment_info.codigo_periodo == 202062)
]
# Out:
#       fake_identificacion  codigo_periodo           curso_nombre  aab1_nota  \
# 15906  SLXA73875862178452          202062  COMUNICACION DE DATOS       1.95
#
#        aab2_nota  acdb1_nota  acdb2_nota  apeb1_nota  apeb2_nota  final_nota  \
# 15906       2.01        3.33        1.35        0.51        1.55         5.3
#
#        aab1_ponderado  aab2_ponderado  acdb1_ponderado  acdb2_ponderado  \
# 15906            19.5            20.1             33.3             13.5
#
#        apeb1_ponderado  apeb2_ponderado  final_ponderado  tasa_aprobacion
# 15906              5.1             15.5             53.0             0.17

# %%
student_info_data[
    (student_info_data.fake_identificacion == 'SLXA73875862178452')
    & (student_info_data.curso_nombre == 'COMUNICACION DE DATOS')
    & (student_info_data.codigo_periodo == 202062)
]
# Out:
#       fake_identificacion  ciclo_academico codigo_programa codigo_malla  \
# 22310  SLXA73875862178452                3         INFO_D1         IFD6
#
#        codigo_periodo     region      zona     centro tipo_de_est_programa  \
# 22310          202062  GUAYAQUIL  GRAN-GYE  GUAYAQUIL             CONTINUO
#
#                    tipo_de_ingreso  periodo_admision    estatus_cursos  \
# 22310  ADAPTACION DE CARRERA/MALLA          202062.0  CURSOS INSCRITOS
#
#       estatus_de_pago descripcion_de_becas  porcentaje_de_beca  \
# 22310  CON PAGO TOTAL                  NaN                 NaN
#
#                                    descripcion_descuento  \
# 22310  DESCUENTO POR NUMERO DE COMPONENTES GRADO DIST...
#
#        porcentaje_des_matricula monto_descuento_automatico  \
# 22310                       5.0                      80.23
#
#       convenios_y_contratos  formas_de_pago      tipo_de_pago    provincia  \
# ...

# %%
student_info_columns = list(student_info_data.columns)
assessment_columns = [
    'aab1_nota', 'aab1_ponderado', 
    'acdb1_nota',  'acdb1_ponderado', 
    'apeb1_nota', 'apeb1_ponderado', 
    'aab2_nota', 'aab2_ponderado', 
    'acdb2_nota', 'acdb2_ponderado', 
    'apeb2_nota', 'apeb2_ponderado',
    'final_nota', 'final_ponderado',
    'tasa_aprobacion'
]
selected_columns = student_info_columns + assessment_columns

# %%
integrated__data_case3 = pd.merge(
    student_info_data,
    assessment_info,
    how = 'inner',
    on = ['fake_identificacion', 'codigo_periodo', 'curso_nombre']
)[selected_columns]

integrated__data_case3[
    (integrated__data_case3.fake_identificacion == 'XTLA48155273548078')
    & (integrated__data_case3.curso_nombre == 'INGENIERIA DE REQUISITOS')
    & (integrated__data_case3.codigo_periodo == 202164)
]
# Out:
#   fake_identificacion  ciclo_academico codigo_programa codigo_malla  \
# 4  XTLA48155273548078                6         INFO_D1         IFD6
#
#    codigo_periodo region        zona           centro tipo_de_est_programa  \
# 4          202164  QUITO  METROPOLIT  QUITO-TURUBAMBA             CONTINUO
#
#                tipo_de_ingreso  periodo_admision    estatus_cursos  \
# 4  ADAPTACION DE CARRERA/MALLA          202062.0  CURSOS INSCRITOS
#
#   estatus_de_pago            descripcion_de_becas  porcentaje_de_beca  \
# 4  CON PAGO TOTAL  CONVENIO DE ADJUDICACIÓN DE BE                10.0
#
#                                descripcion_descuento  \
# 4  DESCUENTO COVID-19  ARANCELES GRADO - DESCUENT...
#
#    porcentaje_des_matricula monto_descuento_automatico  \
# 4                      20.0                      90.26
#
#                                convenios_y_contratos  formas_de_pago  \
# 4  MINISTERIO DEL INTERIOR - POLICIA NACIONAL DEL...  BANCOS ON LINE
#
# ...

# %%
integrated__data_case3.to_csv('integrated-data-case03.csv', index = False)
